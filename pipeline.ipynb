# %% [markdown]
# # 45th solution for Intel & MobileODT Cervical Cancer Screening challenge
# ### Which cancer treatment will be most effective?

# %%
import pandas as pd
import numpy as np
import keras
import matplotlib.pyplot as plt
# %matplotlib inline

from data_preprocessing import preprocess_one_image

# Disable DeprecationWarnings which may be irritating.
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data preprocessing - just see how good unsupervised learning can be.

# %%
# This part is quite expensive. It can take a few minutes to compute it. To preprocess
# all images from training and test sets it is convenient to use preprocess_all_data.py script.

img = plt.imread('/home/maciej/intel_challenge/train/Type_1/0.jpg')
# tile_size make the computation faster, smaller - faster and worser (quality)
img_preprocessed = preprocess_one_image('/home/maciej/intel_challenge/train/Type_1/0.jpg',
                                       tile_size=(1024, 1024)) 
img1 = plt.imread('/home/maciej/intel_challenge/train/Type_2/1006.jpg')
img1_preprocessed = preprocess_one_image('/home/maciej/intel_challenge/train/Type_2/1006.jpg',
                                        tile_size=(1024, 1024))
plt.figure()
plt.suptitle('Images before and after cropping')
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(img_preprocessed)
plt.figure()
plt.subplot(121)
plt.imshow(img1)
plt.subplot(122)
plt.imshow(img1_preprocessed)
plt.show()

# %% [markdown]
# ## Validation - the most important task in this challenge.
